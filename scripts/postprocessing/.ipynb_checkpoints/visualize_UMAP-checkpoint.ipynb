# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

import pandas as pd
from scipy.spatial import cKDTree

# %%
df = pd.read_csv('../../dataset/m_test.csv')

print(df.columns.values)

with open('../../postprocessing/umap.npy', 'rb') as f:
    u = np.load(f)
    
assert u.shape[1] == 2, "UMAP representation has to be 2D"
# Out:
# ['snapshot_id' 'subhalo_id' 'root_descendant_id' 'lookback' 'z'
#  'stellar_age' 'fraction_disk_stars' 'mass_total' 'mass_in_rad'
#  'mass_exsitu' 'snap_num_last_maj_merger' 'mass_last_maj_merger'
#  'mean_merger_lookback_time' 'mean_merger_mass_ratio' 'mass'
#  'lookback_time_last_maj_merger' 'exsitu' 'image_path']

# %%
import matplotlib.pyplot as plt

for label in df.columns.values:
    try:
        plt.scatter(u[:,0], u[:,1], s=10, c=df[label])
        plt.colorbar(label=label)
        plt.show()
    except:
        pass

# %%
NUM_IMAGES_PER_SIDE = 12

u0 = np.linspace(np.min(u[:,0]), np.max(u[:,0]), num=NUM_IMAGES_PER_SIDE)
u1 = np.linspace(np.min(u[:,1]), np.max(u[:,1]), num=NUM_IMAGES_PER_SIDE)

u0v, u1v = np.meshgrid(u0, u1)
print(u0v)
print(u1v)
# Out:
# [[-2.41203952 -1.10621517  0.19960917  1.50543352  2.81125786  4.11708221
#    5.42290655  6.7287309   8.03455524  9.34037958 10.64620393 11.95202827]
#  [-2.41203952 -1.10621517  0.19960917  1.50543352  2.81125786  4.11708221
#    5.42290655  6.7287309   8.03455524  9.34037958 10.64620393 11.95202827]
#  [-2.41203952 -1.10621517  0.19960917  1.50543352  2.81125786  4.11708221
#    5.42290655  6.7287309   8.03455524  9.34037958 10.64620393 11.95202827]
#  [-2.41203952 -1.10621517  0.19960917  1.50543352  2.81125786  4.11708221
#    5.42290655  6.7287309   8.03455524  9.34037958 10.64620393 11.95202827]
#  [-2.41203952 -1.10621517  0.19960917  1.50543352  2.81125786  4.11708221
#    5.42290655  6.7287309   8.03455524  9.34037958 10.64620393 11.95202827]
#  [-2.41203952 -1.10621517  0.19960917  1.50543352  2.81125786  4.11708221
#    5.42290655  6.7287309   8.03455524  9.34037958 10.64620393 11.95202827]
#  [-2.41203952 -1.10621517  0.19960917  1.50543352  2.81125786  4.11708221
#    5.42290655  6.7287309   8.03455524  9.34037958 10.64620393 11.95202827]
#  [-2.41203952 -1.10621517  0.19960917  1.50543352  2.81125786  4.11708221
#    5.42290655  6.7287309   8.03455524  9.34037958 10.64620393 11.95202827]
#  [-2.41203952 -1.10621517  0.19960917  1.50543352  2.81125786  4.11708221
#    5.42290655  6.7287309   8.03455524  9.34037958 10.64620393 11.95202827]
#  [-2.41203952 -1.10621517  0.19960917  1.50543352  2.81125786  4.11708221
#    5.42290655  6.7287309   8.03455524  9.34037958 10.64620393 11.95202827]
#  [-2.41203952 -1.10621517  0.19960917  1.50543352  2.81125786  4.11708221
#    5.42290655  6.7287309   8.03455524  9.34037958 10.64620393 11.95202827]
#  [-2.41203952 -1.10621517  0.19960917  1.50543352  2.81125786  4.11708221
#    5.42290655  6.7287309   8.03455524  9.34037958 10.64620393 11.95202827]]
# [[0.12162608 0.12162608 0.12162608 0.12162608 0.12162608 0.12162608
#   0.12162608 0.12162608 0.12162608 0.12162608 0.12162608 0.12162608]
#  [0.86717414 0.86717414 0.86717414 0.86717414 0.86717414 0.86717414
#   0.86717414 0.86717414 0.86717414 0.86717414 0.86717414 0.86717414]
#  [1.6127222  1.6127222  1.6127222  1.6127222  1.6127222  1.6127222
#   1.6127222  1.6127222  1.6127222  1.6127222  1.6127222  1.6127222 ]
#  [2.35827026 2.35827026 2.35827026 2.35827026 2.35827026 2.35827026
#   2.35827026 2.35827026 2.35827026 2.35827026 2.35827026 2.35827026]
#  [3.10381831 3.10381831 3.10381831 3.10381831 3.10381831 3.10381831
#   3.10381831 3.10381831 3.10381831 3.10381831 3.10381831 3.10381831]
#  [3.84936637 3.84936637 3.84936637 3.84936637 3.84936637 3.84936637
#   3.84936637 3.84936637 3.84936637 3.84936637 3.84936637 3.84936637]
#  [4.59491443 4.59491443 4.59491443 4.59491443 4.59491443 4.59491443
#   4.59491443 4.59491443 4.59491443 4.59491443 4.59491443 4.59491443]
#  [5.34046249 5.34046249 5.34046249 5.34046249 5.34046249 5.34046249
#   5.34046249 5.34046249 5.34046249 5.34046249 5.34046249 5.34046249]
#  [6.08601055 6.08601055 6.08601055 6.08601055 6.08601055 6.08601055
#   6.08601055 6.08601055 6.08601055 6.08601055 6.08601055 6.08601055]
#  [6.83155861 6.83155861 6.83155861 6.83155861 6.83155861 6.83155861
#   6.83155861 6.83155861 6.83155861 6.83155861 6.83155861 6.83155861]
#  [7.57710667 7.57710667 7.57710667 7.57710667 7.57710667 7.57710667
#   7.57710667 7.57710667 7.57710667 7.57710667 7.57710667 7.57710667]
#  [8.32265472 8.32265472 8.32265472 8.32265472 8.32265472 8.32265472
#   8.32265472 8.32265472 8.32265472 8.32265472 8.32265472 8.32265472]]

# %%
tree = cKDTree(u, compact_nodes=False, balanced_tree=False)

filenames = np.empty_like(u0v, dtype=object)
MAX_DISTANCE = 0.2

for i in range(NUM_IMAGES_PER_SIDE):
    for j in range(NUM_IMAGES_PER_SIDE):
        distance, index = tree.query([u0v[i,j], u1v[i,j]], k=[1], p=1, workers=-1)
        
        if distance < MAX_DISTANCE:
            filenames[i,j] = "../." + df['image_path'][index].to_numpy()[0]
        else:
            filenames[i,j] = ""
        
            
print(filenames)
# Out:
# [['' '' '' '' ''
#   '../../dataset_raw/TNG50-1/images/059/shalo_059-342523_v3_HSC_GRIZY.fits'
#   '' '' '' '' '' '']
#  ['' '' '' ''
#   '../../dataset_raw/TNG50-1/images/078/shalo_078-534941_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/063/shalo_063-268772_v2_HSC_GRIZY.fits'
#   '' '' '' '' '' '']
#  ['' '' ''
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-387475_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-351968_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/059/shalo_059-491228_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/078/shalo_078-405920_v0_HSC_GRIZY.fits'
#   '' '' '' '' '']
#  ['' ''
#   '../../dataset_raw/TNG50-1/images/072/shalo_072-497150_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-583249_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-362619_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/063/shalo_063-364361_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-277958_v2_HSC_GRIZY.fits'
#   '' '' '' '' '']
#  ['' ''
#   '../../dataset_raw/TNG50-1/images/063/shalo_063-417733_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-673314_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-632691_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-600688_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/072/shalo_072-349533_v1_HSC_GRIZY.fits'
#   ''
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-527207_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/078/shalo_078-587722_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/063/shalo_063-110445_v2_HSC_GRIZY.fits'
#   '']
#  [''
#   '../../dataset_raw/TNG50-1/images/059/shalo_059-465607_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-513248_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/072/shalo_072-515870_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/072/shalo_072-531976_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/078/shalo_078-540598_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-473441_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-554606_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-606530_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-408736_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-550067_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-659364_v2_HSC_GRIZY.fits']
#  [''
#   '../../dataset_raw/TNG50-1/images/063/shalo_063-481564_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-488076_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/072/shalo_072-459545_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-496423_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/078/shalo_078-505544_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-529373_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/063/shalo_063-462720_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-528702_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-634087_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-180847_v2_HSC_GRIZY.fits'
#   '']
#  ['../../dataset_raw/TNG50-1/images/059/shalo_059-447570_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/063/shalo_063-594880_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/072/shalo_072-611101_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/072/shalo_072-600518_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/072/shalo_072-571206_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/078/shalo_078-554058_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-673523_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-646497_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-519255_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/078/shalo_078-322111_v0_HSC_GRIZY.fits'
#   '' '']
#  ['../../dataset_raw/TNG50-1/images/059/shalo_059-467618_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/059/shalo_059-590358_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-534624_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/072/shalo_072-615956_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/063/shalo_063-470093_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/078/shalo_078-664163_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-689001_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/059/shalo_059-411610_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-658215_v0_HSC_GRIZY.fits'
#   '' '' '']
#  [''
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-566847_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-586985_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/067/shalo_067-523249_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/078/shalo_078-636209_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/059/shalo_059-477555_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/078/shalo_078-624115_v0_HSC_GRIZY.fits'
#   '' '' '' '' '']
#  [''
#   '../../dataset_raw/TNG50-1/images/059/shalo_059-518469_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/059/shalo_059-571953_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/063/shalo_063-556227_v2_HSC_GRIZY.fits'
#   '' '' '' '' '' '' '' '']
#  ['' '' '' '' '' '' '' '' '' '' '' '']]

# %%
import matplotlib.pyplot as plt
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import numpy as np
from astropy.io import fits

def load_image(filename):
    
    def stretch(x):
        x = np.log10(x - np.min(x) + 1)
        x = (x - np.nanmin(x))/(np.nanmax(x)-np.nanmin(x))
        return np.array(x*(2**8), dtype=np.uint8)
    
    with fits.open(filename) as hdul:
            
        G = hdul['SUBARU_HSC.G'].data
        R = hdul['SUBARU_HSC.R'].data
        I = hdul['SUBARU_HSC.I'].data
            
    G = stretch(G)
    R = stretch(R)
    I = stretch(I)

    return np.concatenate((I[...,np.newaxis],R[...,np.newaxis],G[...,np.newaxis]),axis=2)

fig, ax = plt.subplots(figsize=(10., 10.))

ax.set_xlim(u0[0], u0[-1])
ax.set_ylim(u1[0], u1[-1])

for i in range(NUM_IMAGES_PER_SIDE):
    for j in range(NUM_IMAGES_PER_SIDE):
        u0d = u0v[i,j]
        u1d = u1v[i,j]
        filename = filenames[i,j]
        
        if filename != "":
            im = load_image(filename)
            TARGET_IMAGE_SIZE = 60
            zoom_factor = TARGET_IMAGE_SIZE/im.shape[0]
            
            imagebox = OffsetImage(im, zoom=zoom_factor)
            ab = AnnotationBbox(imagebox, (u0d, u1d))
            ax.add_artist(ab)

plt.show()
