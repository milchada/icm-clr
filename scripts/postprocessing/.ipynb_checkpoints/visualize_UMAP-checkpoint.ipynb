# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

import pandas as pd
from scipy.spatial import cKDTree

# %%
df = pd.read_csv('../../dataset/m_test.csv')

print(df.columns.values)

with open('../../postprocessing/umap.npy', 'rb') as f:
    u = np.load(f)
    
assert u.shape[1] == 2, "UMAP representation has to be 2D"
# Out:
# ['snapshot_id' 'subhalo_id' 'root_descendant_id' 'lookback' 'z'
#  'stellar_age' 'fraction_disk_stars' 'mass_total' 'mass_in_rad'
#  'mass_exsitu' 'snap_num_last_maj_merger' 'mass_last_maj_merger'
#  'mean_merger_lookback_time' 'mean_merger_mass_ratio' 'mass'
#  'lookback_time_last_maj_merger' 'exsitu' 'image_path']

# %%
import matplotlib.pyplot as plt

for label in df.columns.values:
    try:
        plt.scatter(u[:,0], u[:,1], s=10, c=df[label])
        plt.colorbar(label=label)
        plt.show()
        
        plt.scatter(u[:,0], u[:,1], s=10, c=np.log10(df[label]))
        plt.colorbar(label=label)
        plt.show()
    except:
        pass

# %%
NUM_IMAGES_PER_SIDE = 12

u0 = np.linspace(np.min(u[:,0]), np.max(u[:,0]), num=NUM_IMAGES_PER_SIDE)
u1 = np.linspace(np.min(u[:,1]), np.max(u[:,1]), num=NUM_IMAGES_PER_SIDE)

u0v, u1v = np.meshgrid(u0, u1)
print(u0v)
print(u1v)
# Out:
# [[ 3.10595608  3.9110964   4.71623672  5.52137704  6.32651737  7.13165769
#    7.93679801  8.74193833  9.54707865 10.35221897 11.1573593  11.96249962]
#  [ 3.10595608  3.9110964   4.71623672  5.52137704  6.32651737  7.13165769
#    7.93679801  8.74193833  9.54707865 10.35221897 11.1573593  11.96249962]
#  [ 3.10595608  3.9110964   4.71623672  5.52137704  6.32651737  7.13165769
#    7.93679801  8.74193833  9.54707865 10.35221897 11.1573593  11.96249962]
#  [ 3.10595608  3.9110964   4.71623672  5.52137704  6.32651737  7.13165769
#    7.93679801  8.74193833  9.54707865 10.35221897 11.1573593  11.96249962]
#  [ 3.10595608  3.9110964   4.71623672  5.52137704  6.32651737  7.13165769
#    7.93679801  8.74193833  9.54707865 10.35221897 11.1573593  11.96249962]
#  [ 3.10595608  3.9110964   4.71623672  5.52137704  6.32651737  7.13165769
#    7.93679801  8.74193833  9.54707865 10.35221897 11.1573593  11.96249962]
#  [ 3.10595608  3.9110964   4.71623672  5.52137704  6.32651737  7.13165769
#    7.93679801  8.74193833  9.54707865 10.35221897 11.1573593  11.96249962]
#  [ 3.10595608  3.9110964   4.71623672  5.52137704  6.32651737  7.13165769
#    7.93679801  8.74193833  9.54707865 10.35221897 11.1573593  11.96249962]
#  [ 3.10595608  3.9110964   4.71623672  5.52137704  6.32651737  7.13165769
#    7.93679801  8.74193833  9.54707865 10.35221897 11.1573593  11.96249962]
#  [ 3.10595608  3.9110964   4.71623672  5.52137704  6.32651737  7.13165769
#    7.93679801  8.74193833  9.54707865 10.35221897 11.1573593  11.96249962]
#  [ 3.10595608  3.9110964   4.71623672  5.52137704  6.32651737  7.13165769
#    7.93679801  8.74193833  9.54707865 10.35221897 11.1573593  11.96249962]
#  [ 3.10595608  3.9110964   4.71623672  5.52137704  6.32651737  7.13165769
#    7.93679801  8.74193833  9.54707865 10.35221897 11.1573593  11.96249962]]
# [[ 5.86061001  5.86061001  5.86061001  5.86061001  5.86061001  5.86061001
#    5.86061001  5.86061001  5.86061001  5.86061001  5.86061001  5.86061001]
#  [ 6.45399683  6.45399683  6.45399683  6.45399683  6.45399683  6.45399683
#    6.45399683  6.45399683  6.45399683  6.45399683  6.45399683  6.45399683]
#  [ 7.04738366  7.04738366  7.04738366  7.04738366  7.04738366  7.04738366
#    7.04738366  7.04738366  7.04738366  7.04738366  7.04738366  7.04738366]
#  [ 7.64077048  7.64077048  7.64077048  7.64077048  7.64077048  7.64077048
#    7.64077048  7.64077048  7.64077048  7.64077048  7.64077048  7.64077048]
#  [ 8.2341573   8.2341573   8.2341573   8.2341573   8.2341573   8.2341573
#    8.2341573   8.2341573   8.2341573   8.2341573   8.2341573   8.2341573 ]
#  [ 8.82754413  8.82754413  8.82754413  8.82754413  8.82754413  8.82754413
#    8.82754413  8.82754413  8.82754413  8.82754413  8.82754413  8.82754413]
#  [ 9.42093095  9.42093095  9.42093095  9.42093095  9.42093095  9.42093095
#    9.42093095  9.42093095  9.42093095  9.42093095  9.42093095  9.42093095]
#  [10.01431777 10.01431777 10.01431777 10.01431777 10.01431777 10.01431777
#   10.01431777 10.01431777 10.01431777 10.01431777 10.01431777 10.01431777]
#  [10.6077046  10.6077046  10.6077046  10.6077046  10.6077046  10.6077046
#   10.6077046  10.6077046  10.6077046  10.6077046  10.6077046  10.6077046 ]
#  [11.20109142 11.20109142 11.20109142 11.20109142 11.20109142 11.20109142
#   11.20109142 11.20109142 11.20109142 11.20109142 11.20109142 11.20109142]
#  [11.79447824 11.79447824 11.79447824 11.79447824 11.79447824 11.79447824
#   11.79447824 11.79447824 11.79447824 11.79447824 11.79447824 11.79447824]
#  [12.38786507 12.38786507 12.38786507 12.38786507 12.38786507 12.38786507
#   12.38786507 12.38786507 12.38786507 12.38786507 12.38786507 12.38786507]]

# %%
tree = cKDTree(u, compact_nodes=False, balanced_tree=False)

filenames = np.empty_like(u0v, dtype=object)
MAX_DISTANCE = 0.2

for i in range(NUM_IMAGES_PER_SIDE):
    for j in range(NUM_IMAGES_PER_SIDE):
        distance, index = tree.query([u0v[i,j], u1v[i,j]], k=[1], p=1, workers=-1)
        
        if distance < MAX_DISTANCE:
            filenames[i,j] = "../." + df['image_path'][index].to_numpy()[0]
        else:
            filenames[i,j] = ""
        
            
print(filenames)
# Out:
# [['' '' '' '' '' '' '' ''
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-474178_v1_HSC_GRIZY.fits'
#   '' '' '']
#  ['' '' '' '' '' '' ''
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-569030_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-590281_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-351320_v1_HSC_GRIZY.fits'
#   '' '']
#  ['' '' '' '' '' ''
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-568304_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-506410_v0_HSC_GRIZY.fits'
#   ''
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-529953_v1_HSC_GRIZY.fits'
#   '' '']
#  ['' '' '' ''
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-521947_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-495328_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-668996_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-541614_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-676417_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-685882_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-706329_v1_HSC_GRIZY.fits'
#   '']
#  ['' ''
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-602875_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-522786_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-665472_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-667466_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-538857_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-509029_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-660358_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-696325_v3_HSC_GRIZY.fits'
#   '' '']
#  ['' ''
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-569252_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-589120_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-634042_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-601614_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-495328_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-718548_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-718026_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-633474_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-590091_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-728234_v0_HSC_GRIZY.fits']
#  [''
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-698713_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-555534_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-661640_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-642504_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-698115_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-602717_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-580614_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-634182_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-649994_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-647379_v1_HSC_GRIZY.fits'
#   '']
#  [''
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-616425_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-576266_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-634048_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-506802_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-624970_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-674054_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-622895_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-665067_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-690987_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-688468_v0_HSC_GRIZY.fits'
#   '']
#  ['../../dataset_raw/TNG50-1/images/091/shalo_091-678391_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-567374_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-505121_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-694957_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-663771_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-665472_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-673485_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-733732_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-579247_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-779338_v2_HSC_GRIZY.fits'
#   '' '']
#  ['../../dataset_raw/TNG50-1/images/091/shalo_091-658747_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-515786_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-694910_v2_HSC_GRIZY.fits'
#   ''
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-623483_v0_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-608917_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/091/shalo_091-686428_v3_HSC_GRIZY.fits'
#   ''
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-667530_v1_HSC_GRIZY.fits'
#   '' '' '']
#  [''
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-524524_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-568023_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-581428_v2_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-576266_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-669122_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-597285_v3_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-661615_v0_HSC_GRIZY.fits'
#   '' '' '' '']
#  ['' '' '' ''
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-666348_v1_HSC_GRIZY.fits'
#   '../../dataset_raw/TNG50-1/images/084/shalo_084-601614_v1_HSC_GRIZY.fits'
#   '' '' '' '' '' '']]

# %%
import matplotlib.pyplot as plt
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import numpy as np
from astropy.io import fits

def load_image(filename):
    
    def get_central_crop(img, num_pixel=20):
        size = img.shape[0]
        center_coordinate = size//2
        upper = center_coordinate + num_pixel//2
        lower = center_coordinate - num_pixel//2
    
        return img[lower:upper, lower:upper]
    
    def stretch(x):
        x[x<=0] = np.nan
        x = np.log10(x)
        x[x<-7] = np.nan
        
        a_min = np.nanmedian(x)
        a_max = np.nanquantile(get_central_crop(x), 0.99)
        
        x = np.nan_to_num(x, nan=a_min, posinf=a_min, neginf=a_min)
        x = np.clip(x, a_min, a_max)
        
        x -= a_min
        x /= (a_max - a_min)
        
        return np.array(x*(2**8 - 1), dtype=np.uint8)
    
    with fits.open(filename) as hdul:
            
        G = hdul['SUBARU_HSC.G'].data
        R = hdul['SUBARU_HSC.R'].data
        I = hdul['SUBARU_HSC.I'].data
            
    G = stretch(G)
    R = stretch(R)
    I = stretch(I)

    return np.concatenate((I[...,np.newaxis],R[...,np.newaxis],G[...,np.newaxis]),axis=2)

fig, ax = plt.subplots(figsize=(20., 20.))

ax.set_xlim(u0[0], u0[-1])
ax.set_ylim(u1[0], u1[-1])

for i in range(NUM_IMAGES_PER_SIDE):
    for j in range(NUM_IMAGES_PER_SIDE):
        u0d = u0v[i,j]
        u1d = u1v[i,j]
        filename = filenames[i,j]
        
        if filename != "":
            im = load_image(filename)
            TARGET_IMAGE_SIZE = 120
            zoom_factor = TARGET_IMAGE_SIZE/im.shape[0]
            
            imagebox = OffsetImage(im, zoom=zoom_factor)
            ab = AnnotationBbox(imagebox, (u0d, u1d))
            ax.add_artist(ab)

plt.show()
# Out:
# /u/leisert/.local/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in less
